# %%
import pandas as pd
df = pd.read_csv("E:\\datascience\\pyhon\\weatherHistory.csv")

# %%
df.head()
# Out:
#          Date        Summary Events  Temperature  ApparentTemperatureC  \
# 0  01-04-2006  Partly Cloudy   rain            9                     7
# 1  01-04-2006  Partly Cloudy   rain            9                     7
# 2  01-04-2006  Mostly Cloudy   rain            9                     9
# 3  01-04-2006  Partly Cloudy   rain            8                     6
# 4  01-04-2006  Mostly Cloudy   rain            9                     7
#
#    Humidity  WindSpeedkm/h  WindBearingdegrees  Visibilitykm  LoudCover  \
# 0       0.9           14.0                 251            16          0
# 1       0.9           14.0                 259            16          0
# 2       0.9            4.0                 204            15          0
# 3       0.8           14.0                 269            16          0
# 4       0.8           11.0                 259            16          0
#
#    Pressuremillibars                       DailySummary
# ...

# %%
df.shape
# Out:
# (1082, 12)

# %%
#max temp

# %%
df["Date"][df["Temperature"].max()]
# Out:
# '10-04-2006'

# %%
df["Date"][df["Events"]=="rain"]
# Out:
# 0       01-04-2006
# 1       01-04-2006
# 2       01-04-2006
# 3       01-04-2006
# 4       01-04-2006
#            ...
# 1077    22-08-2006
# 1078    22-08-2006
# 1079    22-08-2006
# 1080    23-08-2006
# 1081    23-08-2006
# Name: Date, Length: 1082, dtype: object

# %%
df["WindSpeedkm/h"].max()
# Out:
# 32.0

# %%
#display date and max temp

# %%
df[df.Temperature==df.Temperature.max()]
# Out:
#             Date        Summary Events  Temperature  ApparentTemperatureC  \
# 735   01-08-2006  Mostly Cloudy   rain           33                    33
# 953   18-08-2006  Mostly Cloudy   rain           33                    33
# 1021  20-08-2006  Partly Cloudy   rain           33                    35
# 1022  20-08-2006  Partly Cloudy   rain           33                    34
#
#       Humidity  WindSpeedkm/h  WindBearingdegrees  Visibilitykm  LoudCover  \
# 735        0.4           13.0                 199            11          0
# 953        0.4           12.0                 220            10          0
# 1021       0.5           11.0                 252            10          0
# 1022       0.4           14.0                 261            10          0
#
#       Pressuremillibars                                       DailySummary
# 735                1009                  Partly cloudy starting overnight.
# ...

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
#access 2 columns

# %%
df[["Events","DailySummary"]]
# Out:
#      Events                            DailySummary
# 0      rain       Partly cloudy throughout the day.
# 1      rain       Partly cloudy throughout the day.
# 2      rain       Partly cloudy throughout the day.
# 3      rain       Partly cloudy throughout the day.
# 4      rain       Partly cloudy throughout the day.
# ...     ...                                     ...
# 1077   rain  Partly cloudy starting in the morning.
# 1078   rain  Partly cloudy starting in the morning.
# 1079   rain  Partly cloudy starting in the morning.
# 1080   rain  Partly cloudy starting in the morning.
# 1081   rain  Partly cloudy starting in the morning.
#
# [1082 rows x 2 columns]

# %%
df.shape
# Out:
# (1082, 12)

# %%
df.describe()
# Out:
#        Temperature  ApparentTemperatureC     Humidity  WindSpeedkm/h  \
# count  1082.000000           1082.000000  1082.000000    1077.000000
# mean     15.530499             15.201479     0.734935      10.384401
# std       6.344088              6.948075     0.176353       6.309465
# min       1.000000             -1.000000     0.300000       0.000000
# 25%      11.000000             11.000000     0.600000       5.000000
# 50%      15.000000             15.000000     0.800000      10.000000
# 75%      19.000000             19.000000     0.900000      14.000000
# max      33.000000             35.000000     1.000000      32.000000
#
#        WindBearingdegrees  Visibilitykm  LoudCover  Pressuremillibars
# count         1082.000000   1082.000000     1082.0        1082.000000
# mean           201.049908     10.978743        0.0        1007.523105
# std             95.321964      3.373800        0.0          75.363884
# ...

# %%
df[df.Temperature>23]
# Out:
#             Date        Summary Events  Temperature  ApparentTemperatureC  \
# 398   24-04-2006  Partly Cloudy   rain           24                    24
# 399   24-04-2006  Partly Cloudy   rain           24                    24
# 400   24-04-2006  Partly Cloudy   rain           24                    24
# 401   24-04-2006  Partly Cloudy   rain           24                    24
# 422   25-04-2006  Mostly Cloudy   rain           24                    24
# ...          ...            ...    ...          ...                   ...
# 1070  22-08-2006  Partly Cloudy   rain           25                    25
# 1071  22-08-2006  Partly Cloudy   rain           25                    25
# 1072  22-08-2006  Partly Cloudy   rain           25                    25
# 1073  22-08-2006  Partly Cloudy   rain           24                    24
# 1074  22-08-2006  Partly Cloudy   rain           24                    24
#
#       Humidity  WindSpeedkm/h  WindBearingdegrees  Visibilitykm  LoudCover  \
# ...
